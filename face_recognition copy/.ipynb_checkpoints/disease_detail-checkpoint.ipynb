# %%
import numpy as np
import pandas as pd
import os

# %%
dataset = pd.read_csv("/home/shreyanshsatvik/GIT/Centralized-Healtcare-System/face_recognition copy/chatbot-dataset/symptom_Description.csv")

# %%
dataset
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
dataset['Appended'] = dataset['Disease']+"," + dataset['Description']

# %%
dataset
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
dataset = dataset['Appended']

# %%
dataset
# Out:
# 0     Drug Reaction,An adverse drug reaction (ADR) i...
# 1     Malaria,An infectious disease caused by protoz...
# 2     Allergy,An allergy is an immune system respons...
# 3     Hypothyroidism,Hypothyroidism, also called und...
# 4     Psoriasis,Psoriasis is a common skin disorder ...
# 5     GERD,Gastroesophageal reflux disease, or GERD,...
# 6     Chronic cholestasis,Chronic cholestatic diseas...
# 7     hepatitis A,Hepatitis A is a highly contagious...
# 8     Osteoarthristis,Osteoarthritis is the most com...
# 9     (vertigo) Paroymsal  Positional Vertigo,Benign...
# 10    Hypoglycemia, Hypoglycemia is a condition in w...
# 11    Acne,Acne vulgaris is the formation of comedon...
# 12    Diabetes,Diabetes is a disease that occurs whe...
# 13    Impetigo,Impetigo (im-puh-TIE-go) is a common ...
# 14    Hypertension,Hypertension (HTN or HT), also kn...
# 15    Peptic ulcer diseae,Peptic ulcer disease (PUD)...
# 16    Dimorphic hemorrhoids(piles),Hemorrhoids, also...
# ...

# %%
final_str = ""
for i in range(0,len(dataset)):
    final_str += dataset[i]+os.linesep

# %%
final_str
# Out:
# 'Drug Reaction,An adverse drug reaction (ADR) is an injury caused by taking medication. ADRs may occur following a single dose or prolonged administration of a drug or result from the combination of two or more drugs.\nMalaria,An infectious disease caused by protozoan parasites from the Plasmodium family that can be transmitted by the bite of the Anopheles mosquito or by a contaminated needle or transfusion. Falciparum malaria is the most deadly type.\nAllergy,An allergy is an immune system response to a foreign substance that\'s not typically harmful to your body.They can include certain foods, pollen, or pet dander. Your immune system\'s job is to keep you healthy by fighting harmful pathogens.\nHypothyroidism,Hypothyroidism, also called underactive thyroid or low thyroid, is a disorder of the endocrine system in which the thyroid gland does not produce enough thyroid hormone.\nPsoriasis,Psoriasis is a common skin disorder that forms thick, red, bumpy patches covered with silvery s
# ...

# %%
with open("Output_1.txt", "w") as text_file:
    text_file.write(final_str)

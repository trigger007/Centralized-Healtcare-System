# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("/home/shreyanshsatvik/GIT/Centralized-Healtcare-System/face_recognition copy/chatbot-dataset/dataset.csv")

# %%
dataset
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
dataset.drop(dataset.iloc[:, 4:], inplace = True, axis = 1)
dataset
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3
# 0                 skin_rash   nodal_skin_eruptions
# ...

# %%
dataset['Disease'] = "It might be "+ dataset['Disease'].astype(str)

# %%
dataset
# Out:
#                                                 Disease             Symptom_1  \
# 0                          It might be Fungal infection               itching
# 1                          It might be Fungal infection             skin_rash
# 2                          It might be Fungal infection               itching
# 3                          It might be Fungal infection               itching
# 4                          It might be Fungal infection               itching
# ...                                                 ...                   ...
# 4915  It might be (vertigo) Paroymsal  Positional Ve...              vomiting
# 4916                                   It might be Acne             skin_rash
# 4917                It might be Urinary tract infection   burning_micturition
# 4918                              It might be Psoriasis             skin_rash
# 4919                               It might be Impetigo             skin_rash
#
# ...

# %%
dataset['Appended'] = dataset['Symptom_1']+' '+dataset['Symptom_2']+' '+dataset['Symptom_3']

# %%
dataset['joined']=""

# %%
for i in range(len(dataset)):
    l=[]
    l.append(dataset['Appended'][i])
    l.append(dataset['Disease'][i])
    dataset['joined'][i]=l

# %%
#dataset = dataset.drop(columns=['Symptom_1', 'Symptom_2'])
dataset.joined[0]
# Out:
# ['itching  skin_rash  nodal_skin_eruptions', 'It might be Fungal infection']

# %%
dataset
# Out:
#                                                 Disease             Symptom_1  \
# 0                          It might be Fungal infection               itching
# 1                          It might be Fungal infection             skin_rash
# 2                          It might be Fungal infection               itching
# 3                          It might be Fungal infection               itching
# 4                          It might be Fungal infection               itching
# ...                                                 ...                   ...
# 4915  It might be (vertigo) Paroymsal  Positional Ve...              vomiting
# 4916                                   It might be Acne             skin_rash
# 4917                It might be Urinary tract infection   burning_micturition
# 4918                              It might be Psoriasis             skin_rash
# 4919                               It might be Impetigo             skin_rash
#
# ...

# %%
dataset['New_column']= dataset["Appended"]+','+dataset["Disease"].astype(str)
#data = dataset[['New_column', 'Appended']].apply(lambda y: ' '.join(y), axis = 1)

# %%
dataset
# Out:
#                                                 Disease             Symptom_1  \
# 0                          It might be Fungal infection               itching
# 1                          It might be Fungal infection             skin_rash
# 2                          It might be Fungal infection               itching
# 3                          It might be Fungal infection               itching
# 4                          It might be Fungal infection               itching
# ...                                                 ...                   ...
# 4915  It might be (vertigo) Paroymsal  Positional Ve...              vomiting
# 4916                                   It might be Acne             skin_rash
# 4917                It might be Urinary tract infection   burning_micturition
# 4918                              It might be Psoriasis             skin_rash
# 4919                               It might be Impetigo             skin_rash
#
# ...

# %%
dataset = dataset['New_column']

# %%
dataset
# Out:
# 0       itching  skin_rash  nodal_skin_eruptions,It mi...
# 1        skin_rash  nodal_skin_eruptions  dischromic _...
# 2       itching  nodal_skin_eruptions  dischromic _pat...
# 3       itching  skin_rash  dischromic _patches,It mig...
# 4       itching  skin_rash  nodal_skin_eruptions,It mi...
#                               ...
# 4915     vomiting  headache  nausea,It might be (verti...
# 4916     skin_rash  pus_filled_pimples  blackheads,It ...
# 4917     burning_micturition  bladder_discomfort  foul...
# 4918     skin_rash  joint_pain  skin_peeling,It might ...
# 4919     skin_rash  high_fever  blister,It might be Im...
# Name: New_column, Length: 4920, dtype: object

# %%
dataset[0]
# Out:
# 'itching  skin_rash  nodal_skin_eruptions,It might be Fungal infection'

# %%
final_str = ""
for i in range(0,len(dataset)):
    final_str += dataset[i]

# %%
final_str
# Out:
# 'itching  skin_rash  nodal_skin_eruptions,It might be Fungal infection\n skin_rash  nodal_skin_eruptions  dischromic _patches,It might be Fungal infection\nitching  nodal_skin_eruptions  dischromic _patches,It might be Fungal infection\nitching  skin_rash  dischromic _patches,It might be Fungal infection\nitching  skin_rash  nodal_skin_eruptions,It might be Fungal infection\n skin_rash  nodal_skin_eruptions  dischromic _patches,It might be Fungal infection\nitching  nodal_skin_eruptions  dischromic _patches,It might be Fungal infection\nitching  skin_rash  dischromic _patches,It might be Fungal infection\nitching  skin_rash  nodal_skin_eruptions,It might be Fungal infection\nitching  skin_rash  nodal_skin_eruptions,It might be Fungal infection\n continuous_sneezing  shivering  chills,It might be Allergy\n shivering  chills  watering_from_eyes,It might be Allergy\n continuous_sneezing  chills  watering_from_eyes,It might be Allergy\n continuous_sneezing  shivering  watering_from_eyes,
# ...

# %%
with open("Output.txt", "w") as text_file:
    text_file.write(final_str)

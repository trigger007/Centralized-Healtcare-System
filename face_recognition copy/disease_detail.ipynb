# %%
import numpy as np
import pandas as pd
import os

# %%
dataset = pd.read_csv("/home/shreyanshsatvik/GIT/Centralized-Healtcare-System/face_recognition copy/chatbot-dataset/symptom_Description.csv")

# %%
dataset
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
dataset['Appended'] = dataset['Disease']+os.linesep+ dataset['Description']+","

# %%
dataset
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
dataset = dataset['Appended']

# %%
dataset
# Out:
# 0     Drug Reaction\nAn adverse drug reaction (ADR) ...
# 1     Malaria\nAn infectious disease caused by proto...
# 2     Allergy\nAn allergy is an immune system respon...
# 3     Hypothyroidism\nHypothyroidism, also called un...
# 4     Psoriasis\nPsoriasis is a common skin disorder...
# 5     GERD\nGastroesophageal reflux disease, or GERD...
# 6     Chronic cholestasis\nChronic cholestatic disea...
# 7     hepatitis A\nHepatitis A is a highly contagiou...
# 8     Osteoarthristis\nOsteoarthritis is the most co...
# 9     (vertigo) Paroymsal  Positional Vertigo\nBenig...
# 10    Hypoglycemia\n Hypoglycemia is a condition in ...
# 11    Acne\nAcne vulgaris is the formation of comedo...
# 12    Diabetes\nDiabetes is a disease that occurs wh...
# 13    Impetigo\nImpetigo (im-puh-TIE-go) is a common...
# 14    Hypertension\nHypertension (HTN or HT), also k...
# 15    Peptic ulcer diseae\nPeptic ulcer disease (PUD...
# 16    Dimorphic hemorrhoids(piles)\nHemorrhoids, als...
# ...

# %%
final_str = ""
for i in range(0,len(dataset)):
    final_str += dataset[i]+os.linesep

# %%
final_str_1 = ""
for i in range(0,len(final_str)):
    final_str += final_str[i]

# %%
with open("Output_1.txt", "w") as text_file:
    text_file.write(final_str)
